# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm

# %%
reg1=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\AUVERGNE RHONE ALPES.csv')

# %%
reg1
# Out:
# array([6154., 5860., 5620., ..., 8073., 8454., 8632.])

# %%
reg2=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\BOURGOGNE FRANCHE COMTE.csv')
reg3=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\BRETAGNE.csv')
reg4=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\CENTRE VAL DE LOIRE.csv')
reg5=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\GRAND EST.csv')
reg6=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\HAUTS DE FRANCE.csv')
reg7=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\ILE DE FRANCE.csv')
reg8=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\NORMANDIE.csv')
reg9=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\NOUVELLE AQUITAINE.csv')
reg10=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\OCCITANIE.csv')
reg11=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\PAYS DE LA LOIRE.csv')
reg12=pd.read_csv('C:\\Users\\steve\\Downloads\\loadForecastingDataset-eiST4\\dataset_centrale\\data\\test\\PROVENCE ALPES COTE D AZUR.csv')

# %%
reg2=reg2['Consommation']
reg2=np.array(reg2)
reg3=reg3['Consommation']
reg3=np.array(reg3)
reg4=reg4['Consommation']
reg4=np.array(reg4)
reg5=reg5['Consommation']
reg5=np.array(reg5)
reg6=reg6['Consommation']
reg6=np.array(reg6)
reg7=reg7['Consommation']
reg7=np.array(reg7)
reg8=reg8['Consommation']
reg8=np.array(reg8)
reg9=reg9['Consommation']
reg9=np.array(reg9)
reg10=reg10['Consommation']
reg10=np.array(reg10)
re11=reg11['Consommation']
reg11=np.array(reg11)
reg12=reg12['Consommation']
reg12=np.array(reg12)

# %%
sm.graphics.tsa.plot_pacf(reg1, lags=20)
plt.xlabel(r'$lags$',fontsize=16)
plt.ylabel('PACF',fontsize=16)
plt.tick_params(labelsize=14)
plt.show()

# %%
sm.graphics.tsa.plot_acf(reg1)
plt.xlabel(r'$lags$',fontsize=16)
plt.ylabel('ACF',fontsize=16)
plt.tick_params(labelsize=14)
plt.show()

# %%
sm.graphics.tsa.plot_acf(reg2)
sm.graphics.tsa.plot_acf(reg3)
sm.graphics.tsa.plot_acf(reg4)
sm.graphics.tsa.plot_acf(reg5)
sm.graphics.tsa.plot_acf(reg6)
sm.graphics.tsa.plot_acf(reg7)
sm.graphics.tsa.plot_acf(reg8)
sm.graphics.tsa.plot_acf(reg9)
sm.graphics.tsa.plot_acf(reg10)
#sm.graphics.tsa.plot_acf(reg11)
sm.graphics.tsa.plot_acf(reg12)

plt.show()

# %%
sm.graphics.tsa.plot_pacf(reg1)
sm.graphics.tsa.plot_pacf(reg2)
sm.graphics.tsa.plot_pacf(reg3)
sm.graphics.tsa.plot_pacf(reg4)
sm.graphics.tsa.plot_pacf(reg5)
sm.graphics.tsa.plot_pacf(reg6)
sm.graphics.tsa.plot_pacf(reg7)
sm.graphics.tsa.plot_pacf(reg8)
sm.graphics.tsa.plot_pacf(reg9)
sm.graphics.tsa.plot_pacf(reg10)
#sm.graphics.tsa.plot_acf(reg11)
sm.graphics.tsa.plot_pacf(reg12)

plt.show()

# %% [markdown]
# The behavior for all the twelve regions is different from that of an ARMA process
